# %%
import pandas as pd

# %%
df = pd.read_csv("books1.csv")
df["num_reviews"] = df["num_reviews"].str.replace(",", "").astype(int)
df = df.rename(columns = {'alt_title':'book'})

# %% [markdown]
# ### Number of unique userIDs, books, and read books

# %%
df["userID"].unique().shape[0]
# Out:
# 261

# %%
df["book"].unique().shape[0]
# Out:
# 57422

# %%
df[df["shelf"] == "read"]["book"].unique().shape[0]
# Out:
# 26085

# %% [markdown]
# ### Table for data screenshot

# %%
df[df["userID"] == "85957352"].drop("Unnamed: 0", axis=1)
# Out:
# Empty DataFrame
# Columns: [userID, shelf, title, book, author, avg_rating, num_reviews, rating, date_added, date_read]
# Index: []

# %%
test = df[df["userID"] == "124344532"].drop("Unnamed: 0", axis=1).tail()
test["userID"] = "exampleID"
test
# Out:
#           userID    shelf                                              title  \
# 58413  exampleID  to-read                 \n      Tolkien on Fairy-stories\n
# 58414  exampleID  to-read  \n      Antifragile: Things That Gain from Dis...
# 58415  exampleID  to-read                                                NaN
# 58416  exampleID  to-read                                                NaN
# 58417  exampleID  to-read  \n      Gödel, Escher, Bach: an Eternal Golden...
#
#                                                book                  author  \
# 58413                      Tolkien on Fairy-stories         Tolkien, J.R.R.
# 58414   Antifragile: Things That Gain from Disorder  Taleb, Nassim Nicholas
# 58415                Consider Phlebas (Culture, #1)          Banks, Iain M.
# 58416   A Fire Upon the Deep (Zones of Thought, #1)           Vinge, Vernor
# 58417  Gödel, Escher, Bach: an Eternal Golden Braid  Hofstadter, Douglas R.
#
#        avg_rating  num_reviews rating           date_added date_read
# 58413        4.30         2870    NaN  2020-11-09 00:00:00   not set
# 58414        4.09        38581    NaN  2020-11-09 00:00:00   not set
# 58415        3.86        77082    NaN  2020-11-09 00:00:00   not set
# 58416        4.13        53275    NaN  2020-11-09 00:00:00   not set
# 58417        4.27        44380    NaN  2020-11-09 00:00:00   not set

# %% [markdown]
# ## Most read books

# %%
df_most_read = df[df["shelf"] == "read"].groupby(["book"]).count().sort_values(by=["userID"], ascending=False).drop("Unnamed: 0", axis=1)
to_drop = ['shelf', 'title', 'author', 'avg_rating', 'num_reviews',
       'rating', 'date_added', 'date_read']
df_most_read.head(40).drop(to_drop, axis=1).rename(columns = {'userID':'n'})
# Out:
#                                                       n
# book
# 1984                                                120
# Thinking, Fast and Slow                             112
# Animal Farm                                          97
# Superintelligence: Paths, Dangers, Strategies        92
# Sapiens: A Brief History of Humankind                91
# Harry Potter and the Sorcerer's Stone (Harry Po...   86
# Brave New World                                      83
# Doing Good Better: How Effective Altruism Can H...   82
# The Hitchhiker's Guide to the Galaxy (Hitchhike...   80
# Harry Potter and the Prisoner of Azkaban (Harry...   75
# Freakonomics: A Rogue Economist Explores the Hi...   74
# The Great Gatsby                                     72
# The Precipice: Existential Risk and the Future ...   70
# Harry Potter and the Chamber of Secrets (Harry ...   70
# Harry Potter and the Goblet of Fire (Harry Pott...   68
# Ender's Game (Ender's Saga, #1)                      66
# Superforecasting: The Art and Science of Predic...   66
# The Catcher in the Rye                               65
# Harry Potter and the Half-Blood Prince (Harry P...   65
# How to Win Friends and Influence People              64
# Lord of the Flies                                    64
# Harry Potter and the Deathly Hallows (Harry Pot...   64
# Harry Potter and the Methods of Rationality          62
# Harry Potter and the Order of the Phoenix (Harr...   62
# Slaughterhouse-Five                                  61
# The Fellowship of the Ring (The Lord of the Rin...   60
# The Hobbit, or There and Back Again                  58
# Fahrenheit 451                                       58
# The Hunger Games (The Hunger Games, #1)              57
# To Kill a Mockingbird                                57
# Man's Search for Meaning                             56
# Deep Work: Rules for Focused Success in a Distr...   54
# The Alchemist                                        52
# A Game of Thrones (A Song of Ice and Fire, #1)       51
# Poor Economics: A Radical Rethinking of the Way...   50
# The Selfish Gene                                     49
# The God Delusion                                     48
# Outliers: The Story of Success                       48
# The Little Prince                                    47
# The Da Vinci Code (Robert Langdon, #2)               47

# %% [markdown]
# ## Most planned to read

# %%
to_drop = ['shelf', 'title', 'author', 'avg_rating', 'num_reviews',
       'rating', 'date_added', 'date_read', "Unnamed: 0"]
df[df["shelf"] == "to-read"].groupby(["book"]).count().sort_values(by=["userID"], ascending=False).head(40).drop(to_drop, axis=1).rename(columns = {'userID':'n'})
# Out:
#                                                      n
# book
# The Better Angels of Our Nature: Why Violence H...  61
# Gödel, Escher, Bach: an Eternal Golden Braid        55
# Superforecasting: The Art and Science of Predic...  55
# Reasons and Persons                                 53
# Man's Search for Meaning                            48
# Factfulness: Ten Reasons We're Wrong About the ...  47
# Guns, Germs, and Steel: The Fates of Human Soci...  46
# Why Nations Fail: The Origins of Power, Prosper...  46
# Brave New World                                     43
# Algorithms to Live By: The Computer Science of ...  43
# The Signal and the Noise: Why So Many Predictio...  41
# Influence: The Psychology of Persuasion             41
# The Precipice: Existential Risk and the Future ...  41
# Sapiens: A Brief History of Humankind               41
# Predictably Irrational: The Hidden Forces That ...  41
# Superintelligence: Paths, Dangers, Strategies       41
# The Structure of Scientific Revolutions             40
# Catch-22                                            40
# Seeing Like a State: How Certain Schemes to Imp...  40
# Enlightenment Now: The Case for Reason, Science...  40
# The Righteous Mind: Why Good People Are Divided...  38
# The Tipping Point: How Little Things Can Make a...  37
# Homo Deus: A History of Tomorrow                    37
# The Black Swan: The Impact of the Highly Improb...  37
# Poor Economics: A Radical Rethinking of the Way...  36
# Meditations                                         36
# The Selfish Gene                                    36
# Thinking, Fast and Slow                             35
# Moral Uncertainty                                   35
# The Brothers Karamazov                              35
# Antifragile: Things That Gain from Disorder         34
# Moral Tribes: Emotion, Reason, and the Gap Betw...  34
# The Case Against Education: Why the Education S...  34
# Crime and Punishment                                34
# The Blank Slate: The Modern Denial of Human Nature  33
# Atomic Habits: An Easy & Proven Way to Build Go...  33
# Flow: The Psychology of Optimal Experience          33
# War and Peace                                       33
# Behave: The Biology of Humans at Our Best and W...  33
# Life 3.0: Being Human in the Age of Artificial ...  33

# %% [markdown]
# ## Planned-to-read/Have-read Ratio, or: Maybe more people want to read those books?

# %%
df_merged = df[df["shelf"] == "to-read"].groupby(["book"]).count().merge(
    df[df["shelf"] == "read"].groupby(["book"]).count(), on=["book"])
df_ratios = pd.DataFrame(df_merged["userID_x"]/df_merged["userID_y"], columns=["ratio"])#.sort_values(by="ratio", ascending=False).head(30).round(2)

# %%
drop_them = list(df_most_read.columns)
drop_them.remove("userID")
drop_them
# Out:
# ['shelf',
#  'title',
#  'author',
#  'avg_rating',
#  'num_reviews',
#  'rating',
#  'date_added',
#  'date_read']

# %%
df_ratios.merge(df_most_read, on=["book"]).sort_values(by="ratio", ascending=False).head(50).drop(drop_them, axis=1).rename(columns = {'userID':'n'})
# Out:
#                                                     ratio  n
# book
# Rationality and the Reflective Mind                  25.0  1
# Probability Theory                                   22.0  1
# The Rise and Fall of American Growth: The U.S. ...   21.0  1
# The Evolution of Cooperation                         18.0  1
# Poor Charlie's Almanack: The Wit and Wisdom of ...   16.0  1
# Collapse of Complex Societies                        15.0  1
# The Denial of Death                                  15.0  1
# The True Believer: Thoughts on the Nature of Ma...   14.0  1
# The Federalist Papers                                14.0  1
# The Effective Executive: The Definitive Guide t...   14.0  1
# The Art of Doing Science and Engineering: Learn...   14.0  1
# Diplomacy                                            14.0  1
# The Value of Everything: Making and Taking in t...   14.0  1
# The Discourses                                       13.0  1
# But What If We're Wrong? Thinking About the Pre...   13.0  1
# Crowds and Power                                     13.0  1
# Swann's Way                                          13.0  1
# The Power of Myth                                    13.0  1
# Judgment Under Uncertainty: Heuristics and Biases    12.5  2
# The Meme Machine                                     12.0  1
# Thinking Physics: Understandable Practical Reality   12.0  1
# Reinforcement Learning: An Introduction              12.0  1
# The Art of Not Being Governed: An Anarchist His...   12.0  1
# The Idea of Justice                                  12.0  1
# The Theory of Moral Sentiments                       12.0  1
# Business Adventures                                  12.0  1
# The Master and His Emissary: The Divided Brain ...   12.0  1
# Arms and Influence                                   12.0  1
# Rational Choice in an Uncertain World: The Psyc...   12.0  1
# The Protestant Ethic and the Spirit of Capitalism    12.0  1
# War and Peace and War: The Rise and Fall of Emp...   12.0  1
# Conversations on Consciousness: What the Best M...   12.0  1
# The Man Without Qualities                            12.0  1
# The Open Society and Its Enemies                     11.0  1
# The Infidel and the Professor: David Hume, Adam...   11.0  1
# Proofs and Refutations: The Logic of Mathematic...   11.0  1
# Language in Thought and Action                       11.0  1
# The Model Thinker: What You Need to Know to Mak...   11.0  1
# Exit, Voice, and Loyalty: Responses to Decline ...   11.0  1
# Introduction to the Theory of Computation            11.0  1
# The Tale of Genji                                    11.0  1
# Order Without Design: How Markets Shape Cities       11.0  1
# Strategy                                             10.0  1
# Private Truths, Public Lies: The Social Consequ...   10.0  1
# The Road to Reality: A Complete Guide to the La...   10.0  2
# The Future of Capitalism: Facing the New Anxieties   10.0  1
# Darkness at Noon                                     10.0  1
# Being and Nothingness                                10.0  2
# 10% Less Democracy: Why You Should Trust Elites...   10.0  1
# This Is Your Brain on Music: The Science of a H...   10.0  1

# %%
df_ratios.merge(df_most_read[df_most_read["userID"] > 1], on=["book"]).sort_values(by="ratio", ascending=False).head(40).drop(drop_them, axis=1).round(2).rename(columns = {'userID':'n'})
# Out:
#                                                     ratio  n
# book
# Judgment Under Uncertainty: Heuristics and Biases   12.50  2
# The Road to Reality: A Complete Guide to the La...  10.00  2
# Being and Nothingness                               10.00  2
# An Inquiry into the Nature and Causes of the We...   9.50  2
# The Logic of Scientific Discovery                    9.00  2
# The Second Sex                                       8.50  2
# Moneyball: The Art of Winning an Unfair Game         8.50  2
# Structures: Or Why Things Don't Fall Down            8.00  2
# On What Matters, Volume One                          8.00  3
# Complexity: A Guided Tour                            7.50  2
# The Origins of Happiness: The Science of Well-B...   7.50  2
# The Hidden Life of Trees: What They Feel, How T...   7.50  2
# The Origins of Totalitarianism                       7.33  3
# The Big Picture: On the Origins of Life, Meanin...   7.33  3
# Loonshots: How to Nurture the Crazy Ideas That ...   7.00  2
# On What Matters: Volume Two                          7.00  2
# The Society of Mind                                  7.00  3
# As I Lay Dying                                       7.00  2
# The Great Mental Models: General Thinking Concepts   7.00  2
# Maps of Meaning: The Architecture of Belief          7.00  2
# Gravity's Rainbow                                    7.00  3
# Bowling Alone: The Collapse and Revival of Amer...   7.00  2
# Micromotives and Macrobehavior                       6.50  2
# Dark Money: The Hidden History of the Billionai...   6.50  2
# How Asia Works: Success and Failure in the Worl...   6.50  2
# Legal Systems Very Different From Ours               6.50  2
# After Virtue: A Study in Moral Theory                6.50  2
# Salt: A World History                                6.50  2
# The Overstory                                        6.50  2
# The Cultural Revolution: A People's History, 19...   6.50  2
# The Strategy of Conflict: With a New Preface by...   6.50  4
# Probabilistic Reasoning in Intelligent Systems:...   6.50  2
# The Sixth Extinction: An Unnatural History           6.33  3
# Effective Altruism. Philosophical Issues             6.00  2
# Maxims                                               6.00  2
# Irrational Exuberance                                6.00  2
# Maybe You Should Talk to Someone: A Therapist, ...   6.00  2
# The Feynman Lectures on Physics                      6.00  4
# At the Existentialist Café: Freedom, Being, and...   6.00  2
# The Paper Menagerie and Other Stories                6.00  2

# %%
pd.DataFrame(df_merged["userID_x"]/df_merged["userID_y"], columns=["ratio"]).sort_values(by="ratio", ascending=True).head(20).round(2)
# Out:
#                                                     ratio
# book
# Harry Potter and the Prisoner of Azkaban (Harry...   0.01
# Harry Potter and the Chamber of Secrets (Harry ...   0.01
# Harry Potter and the Goblet of Fire (Harry Pott...   0.01
# Harry Potter and the Half-Blood Prince (Harry P...   0.02
# Harry Potter and the Deathly Hallows (Harry Pot...   0.02
# Harry Potter and the Order of the Phoenix (Harr...   0.02
# The Fellowship of the Ring (The Lord of the Rin...   0.02
# Harry Potter and the Sorcerer's Stone (Harry Po...   0.02
# The Return of the King (The Lord of the Rings, #3)   0.03
# Artemis Fowl (Artemis Fowl, #1)                      0.04
# Mort (Discworld, #4; Death, #1)                      0.04
# A Clash of Kings  (A Song of Ice and Fire, #2)       0.04
# A Storm of Swords (A Song of Ice and Fire, #3)       0.04
# A Dance with Dragons (A Song of Ice and Fire, #5)    0.04
# The Amber Spyglass                                   0.04
# The Hero of Ages (Mistborn, #3)                      0.05
# A Feast for Crows (A Song of Ice and Fire, #4)       0.05
# Eragon (The Inheritance Cycle, #1)                   0.05
# Words of Radiance (The Stormlight Archive, #2)       0.06
# Digital Fortress                                     0.06

# %% [markdown]
# ### Most wanted books that have never been read

# %%
to_drop = ['shelf', 'title', 'author', 'avg_rating', 'num_reviews',
       'rating', 'date_added', 'date_read', "Unnamed: 0"]

# %%
common = df[df["shelf"] == "to-read"].merge(df[df["shelf"] == "read"],on=['book'])
df[df["shelf"] == "to-read"][(~df[df["shelf"] == "to-read"].book.isin(common.book))]\
        .groupby(["book"]).count().sort_values(by=["userID"], ascending=False).head(40).drop(to_drop, axis=1).rename(columns = {'userID':'n'})
# Out:
#                                                      n
# book
# Energy and Civilization: A History                  21
# The Scout Mindset: Why Some People See Things C...  19
# The Great Transformation: The Political and Eco...  18
# The Human Condition                                 16
# Think Again: The Power of Knowing What You Don'...  16
# The Oxford Handbook of Thinking and Reasoning       15
# Simulacra and Simulation                            14
# The Innovator's Dilemma: The Revolutionary Book...  13
# The General Theory of Employment, Interest, and...  13
# Bury My Heart at Wounded Knee: An Indian Histor...  13
# Reinventing Organizations: A Guide to Creating ...  13
# The Decline and Fall of the Roman Empire            12
# Growth: From Microorganisms to Megacities           12
# On Certainty                                        12
# Complexity: The Emerging Science at the Edge of...  11
# Entangled Life: How Fungi Make Our Worlds, Chan...  11
# Why Greatness Cannot Be Planned: The Myth of th...  11
# The World as Will and Representation, Vol. 1        11
# A Vindication of the Rights of Woman                11
# The Rise and Fall of the Great Powers: Economic...  10
# Grand Futures                                       10
# The Perennial Philosophy                            10
# The Doors of Stone (The Kingkiller Chronicle, #3)   10
# Mathematics: Its Content, Methods and Meaning       10
# The Rise and Fall of the Dinosaurs: A New Histo...  10
# Infinite Powers: How Calculus Reveals the Secre...  10
# Theory of Games and Economic Behavior               10
# A Pattern Language: Towns, Buildings, Construction  10
# Trick Mirror: Reflections on Self-Delusion          10
# Das Kapital                                         10
# Praise of Folly                                     10
# The Anatomy of Melancholy                           10
# The Sciences of the Artificial                       9
# How Buildings Learn: What Happens After They're...   9
# Human Action: A Treatise on Economics                9
# Endless Forms Most Beautiful: The New Science o...   9
# Absalom, Absalom!                                    9
# The Decline of the West                              9
# The Infinite Game                                    9
# Ordinary Men: Reserve Police Battalion 101 and ...   9

# %% [markdown]
# ## Highest rated

# %%
df["rating"].unique()
# Out:
# array(['liked it', 'really liked it', 'it was ok', 'it was amazing',
#        'did not like it', nan], dtype=object)

# %%
df = df.replace({"liked it": 3, "really liked it": 4, "it was ok": 2, "it was amazing": 5, "did not like it": 1})

# %%
relevant_titles = list(df_most_read[df_most_read["userID"] > 10].index)

# %%
to_drop = ['avg_rating_x', 'num_reviews_x', 'userID_x', 'shelf_x',
       'title_x', 'author_x', 'avg_rating_y', 'num_reviews_y', 'rating_y',
       'date_added_x', 'date_read_x', 'shelf_y', 'title_y',
       'author_y', 'rating', 'date_added_y', 'date_read_y', "Unnamed: 0", "avg_rating", "num_reviews"]

# %%
df.groupby(["book"]).mean().merge(df_most_read, on=["book"]).merge(df_most_read, on=["book"]).loc[relevant_titles].sort_values(by=["rating_x"], ascending=False).head(40).drop(to_drop, axis=1).round(2).rename(columns = {'userID_y':'n', 'rating_x': 'rating'})
# Out:
#                                                     rating    n
# book
# Famine, Affluence, and Morality                       4.85   20
# Doing Good Better: How Effective Altruism Can H...    4.83   82
# Mother of Learning                                    4.82   11
# All the Light We Cannot See                           4.78   11
# The Precipice: Existential Risk and the Future ...    4.77   70
# Harry Potter and the Methods of Rationality           4.75   62
# Reasons and Persons                                   4.74   19
# The Ultimate Hitchhiker's Guide to the Galaxy (...    4.73   23
# Worm (Parahumans, #1)                                 4.70   23
# Mindfulness in Plain English                          4.70   11
# Infinite Jest                                         4.69   14
# Watchmen                                              4.67   30
# The Better Angels of Our Nature: Why Violence H...    4.66   38
# A Storm of Swords (A Song of Ice and Fire, #3)        4.65   23
# Born a Crime: Stories From a South African Chil...    4.65   17
# Oathbringer (The Stormlight Archive, #3)              4.62   16
# How to Measure Anything: Finding the Value of "...    4.62   20
# Stories of Your Life and Others                       4.62   36
# Factfulness: Ten Reasons We're Wrong About the ...    4.62   42
# A Deepness in the Sky (Zones of Thought, #2)          4.62   13
# Evicted: Poverty and Profit in the American City      4.60   12
# The Blank Slate: The Modern Denial of Human Nature    4.59   25
# Thinking, Fast and Slow                               4.59  112
# The Life You Can Save: Acting Now to End World ...    4.58   41
# Life 3.0: Being Human in the Age of Artificial ...    4.57   23
# 80,000 Hours: Find a fulfilling career that doe...    4.56   34
# The Selfish Gene                                      4.56   49
# Animal Liberation                                     4.56   30
# Gödel, Escher, Bach: an Eternal Golden Braid          4.56   25
# Waiting for Godot                                     4.56   12
# Three Worlds Collide                                  4.56   38
# V for Vendetta                                        4.56   12
# Getting to Yes: Negotiating Agreement Without G...    4.56   11
# Bad Blood: Secrets and Lies in a Silicon Valley...    4.55   24
# The Righteous Mind: Why Good People Are Divided...    4.55   43
# The Blind Watchmaker: Why the Evidence of Evolu...    4.55   12
# The Phantom Tollbooth                                 4.55   14
# The Replacing Guilt Series                            4.55   11
# Rationality: From AI to Zombies                       4.54   35
# An Enquiry Concerning Human Understanding             4.53   15

# %% [markdown]
# ### Lowest rated

# %%
df.groupby(["book"]).mean().merge(df_most_read, on=["book"]).merge(df_most_read, on=["book"]).loc[relevant_titles].sort_values(by=["rating_x"], ascending=True).head(30).drop(to_drop, axis=1).round(2).rename(columns = {'userID_y':'n', 'rating_x': 'rating'})
# Out:
#                                                     rating   n
# book
# New Moon (Twilight, #2)                               1.83  11
# The Secret (The Secret, #1)                           1.85  13
# Twilight (Twilight, #1)                               1.86  26
# Eldest (The Inheritance Cycle, #2)                    2.70  12
# Anthem                                                2.90  14
# The Communist Manifesto                               2.95  25
# Stardust                                              3.00  12
# A Midsummer Night's Dream                             3.00  11
# The Da Vinci Code (Robert Langdon, #2)                3.03  47
# Eragon (The Inheritance Cycle, #1)                    3.07  39
# On Bullshit                                           3.07  14
# The Ethical Slut: A Guide to Infinite Sexual Po...    3.08  13
# Skin in the Game: The Hidden Asymmetries in Dai...    3.10  11
# The Gunslinger                                        3.10  11
# Atlas Shrugged                                        3.11  20
# The Lovely Bones                                      3.11  11
# Tuesdays with Morrie                                  3.12  11
# The Obstacle Is the Way: The Timeless Art of Tu...    3.13  15
# The Scarlet Letter                                    3.15  15
# The Five People You Meet in Heaven                    3.17  13
# The Fountainhead                                      3.17  25
# Divergent (Divergent, #1)                             3.18  14
# A Mathematician's Apology                             3.20  11
# Angels & Demons (Robert Langdon, #1)                  3.21  32
# Heart of Darkness                                     3.22  26
# The Crucible                                          3.25  12
# Me Talk Pretty One Day                                3.27  12
# 12 Rules for Life: An Antidote to Chaos               3.29  28
# The Lost Symbol (Robert Langdon, #3)                  3.30  12
# Life of Pi                                            3.31  28

# %% [markdown]
# ## Fringe books read by EAs

# %%
df_most_read_only = df_most_read[df_most_read["userID"] > 10]

# %%
to_drop = ['shelf', 'title', 'author', 'avg_rating_y',
       'num_reviews_y', 'rating_y', 'date_added', 'date_read', "avg_rating_x", "rating_x"]

# %%
df.groupby(["book"]).mean().round(0).drop("Unnamed: 0", axis=1).merge(df_most_read_only, on="book")\
    .sort_values(by="num_reviews_x", ascending=True).head(30).drop(to_drop, axis=1).astype(int)\
    .rename(columns = {'num_reviews_x':'G. reviews', 'userID': 'EA reads'})
# Out:
#                                                     G. reviews  EA reads
# book
# The Replacing Guilt Series                                  45        11
# Effective Altruism Handbook                                108        16
# The Less Wrong Sequences                                   203        13
# Crystal Mentality (Crystal Trilogy, #2)                    215        13
# Global Catastrophic Risks                                  217        12
# The AI Does Not Hate You: Superintelligence, Ra...         231        20
# What Intelligence Tests Miss: The Psychology of...         236        13
# …And I Show You How Deep the Rabbit Hole Goes              246        11
# The Sword of Good                                          312        11
# Smarter Than Us: The Rise of Machine Intelligence          370        16
# The End of Animal Farming: How Scientists, Entr...         383        13
# The Age of Em: Work, Love and Life When Robots ...         453        19
# The Fable of the Dragon-Tyrant                             488        29
# Famine, Affluence, and Morality                            498        20
# Luminosity (Luminosity, #1)                                502        14
# Expert Political Judgment: How Good Is It? How ...         535        15
# Crystal Society (Crystal Trilogy, #1)                      585        22
# How to Create a Vegan World: A Pragmatic Approach          613        11
# The Metropolitan Man                                       632        25
# A Girl Corrupted by the Internet is the Summone...         777        19
# 80,000 Hours: Find a fulfilling career that doe...         797        34
# Ra                                                         798        11
# Inadequate Equilibria: Where and How Civilizati...         975        35
# Radical Markets: Uprooting Capitalism and Democ...         985        21
# Focusing                                                  1000        13
# The Secret of Our Success: How Culture Is Drivi...        1037        17
# Unsong                                                    1055        32
# Stubborn Attachments: A Vision for a Society of...        1095        20
# Three Worlds Collide                                      1194        38
# The Precipice: Existential Risk and the Future ...        1248        70
